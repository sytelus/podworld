# %%
# %matplotlib notebook
import tensorwatch as tw
client = tw.WatcherClient(filename='random_agent.log')

# %%
s0 = client.open_stream(name='reward')
v0 = tw.Visualizer(stream=s0)
v0.show()
# Out:
# [Debug][0]: FileStream started : /home/shitals/GitHubSrc/podworld/random_agent.log : t=1.14
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Output(),))
